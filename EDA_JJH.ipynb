# %%
import pandas as pd


df = pd.read_csv('../EDA_Prj/DATASET/서울지역별_아파트거래.csv')
#df = pd.read_csv('../EDA_Prj/DATASET/거래량.csv')
#df = pd.read_csv('../EDA_Prj/DATASET/월간주택가격동향.csv')
#df = pd.read_csv('../EDA_Prj/DATASET/건물용도별_거래량.csv')
#df = pd.read_excel('../EDA_Prj/DATASET/평균단위매매가격_아파트.xlsx')
#df = pd.read_excel('../EDA_Prj/DATASET/평균단위전세가격_아파트.xlsx')
#df = pd.read_excel('../EDA_Prj/DATASET/평균매매가격_아파트.xlsx')
#df = pd.read_excel('../EDA_Prj/DATASET/평균월세가격_아파트.xlsx')
#df = pd.read_excel('../EDA_Prj/DATASET/평균월세보증금_아파트.xlsx')
#df = pd.read_excel('../EDA_Prj/DATASET/평균전세가격_아파트.xlsx')

df
# Out:
#      기준연도  기준월 면적/동(호)      전국     서울  종로구   중구  용산구  성동구  광진구  ...   강서구  \
# 0    2018  01월      면적  134312  18212  114  197  760  610  254  ...   543
# 1    2018  01월    동(호)   10395   1429    9   15   69   50   22  ...    39
# 2    2018  02월      면적  113363  15305  103  227  850  614  273  ...   730
# 3    2018  02월    동(호)    8698   1181    8   18   58   49   23  ...    53
# 4    2018  03월      면적  135730  20673  130  367  950  677  298  ...  1038
# ..    ...  ...     ...     ...    ...  ...  ...  ...  ...  ...  ...   ...
# 145  2024  01월    동(호)    4901    391    2    3    6   13    6  ...    10
# 146  2024  02월      면적   57105   5024   25   55   58  784   75  ...   181
# 147  2024  02월    동(호)    4243    363    2    4    6   49    6  ...    12
# 148  2024  03월      면적   65162   4464   43   64   69  295  152  ...   177
# 149  2024  03월    동(호)    4848    315    3    4    7   18   14  ...    12
#
#       구로구   금천구  영등포구  동작구  관악구   서초구   강남구   송파구     강동구
# ...

# %%
data = df.copy()

# %%
data_filtered = data.iloc[:].copy()
data_filtered
# Out:
#      기준연도  기준월 면적/동(호)      전국     서울  종로구   중구  용산구  성동구  광진구  ...   강서구  \
# 0    2018  01월      면적  134312  18212  114  197  760  610  254  ...   543
# 1    2018  01월    동(호)   10395   1429    9   15   69   50   22  ...    39
# 2    2018  02월      면적  113363  15305  103  227  850  614  273  ...   730
# 3    2018  02월    동(호)    8698   1181    8   18   58   49   23  ...    53
# 4    2018  03월      면적  135730  20673  130  367  950  677  298  ...  1038
# ..    ...  ...     ...     ...    ...  ...  ...  ...  ...  ...  ...   ...
# 145  2024  01월    동(호)    4901    391    2    3    6   13    6  ...    10
# 146  2024  02월      면적   57105   5024   25   55   58  784   75  ...   181
# 147  2024  02월    동(호)    4243    363    2    4    6   49    6  ...    12
# 148  2024  03월      면적   65162   4464   43   64   69  295  152  ...   177
# 149  2024  03월    동(호)    4848    315    3    4    7   18   14  ...    12
#
#       구로구   금천구  영등포구  동작구  관악구   서초구   강남구   송파구     강동구
# ...

# %%
data_filtered['서울'] = data_filtered['서울'].astype(str)
data

data_filtered
# Out:
#      기준연도  기준월 면적/동(호)      전국     서울  종로구   중구  용산구  성동구  광진구  ...   강서구  \
# 0    2018  01월      면적  134312  18212  114  197  760  610  254  ...   543
# 1    2018  01월    동(호)   10395   1429    9   15   69   50   22  ...    39
# 2    2018  02월      면적  113363  15305  103  227  850  614  273  ...   730
# 3    2018  02월    동(호)    8698   1181    8   18   58   49   23  ...    53
# 4    2018  03월      면적  135730  20673  130  367  950  677  298  ...  1038
# ..    ...  ...     ...     ...    ...  ...  ...  ...  ...  ...  ...   ...
# 145  2024  01월    동(호)    4901    391    2    3    6   13    6  ...    10
# 146  2024  02월      면적   57105   5024   25   55   58  784   75  ...   181
# 147  2024  02월    동(호)    4243    363    2    4    6   49    6  ...    12
# 148  2024  03월      면적   65162   4464   43   64   69  295  152  ...   177
# 149  2024  03월    동(호)    4848    315    3    4    7   18   14  ...    12
#
#       구로구   금천구  영등포구  동작구  관악구   서초구   강남구   송파구     강동구
# ...

# %%
data_filtered.to_csv('data_filtered')

# %%
df2 = pd.read_csv('../EDA_Prj/DATASET/월간주택가격동향.csv')
df2
# Out:
#     기준연도  기준월   매매상승률  매매지수   전세상승률  전세지수   월세상승률   월세지수
# 0   2024    3  -0.12%  95.8   0.05%  92.6   0.09%  102.0
# 1   2024    2  -0.14%  95.9   0.03%  92.6   0.10%  101.9
# 2   2024    1  -0.14%  96.0   0.05%  92.5   0.07%  101.8
# 3   2023   12  -0.10%  96.2   0.12%  92.5   0.10%  101.7
# 4   2023   11   0.04%  96.3   0.27%  92.4   0.14%  101.6
# ..   ...  ...     ...   ...     ...   ...     ...    ...
# 70  2018    5  -0.03%  90.1  -0.28%  94.8  -0.12%   99.5
# 71  2018    4   0.06%  90.1  -0.19%  95.1  -0.10%   99.6
# 72  2018    3   0.12%  90.1  -0.13%  95.2  -0.07%   99.7
# 73  2018    2   0.20%  90.0  -0.09%  95.4  -0.05%   99.7
# 74  2018    1   0.14%  89.8  -0.05%  95.5  -0.04%   99.8
#
# [75 rows x 8 columns]

# %%
df2 = pd.read_csv('../EDA_Prj/DATASET/거래량.csv')
df2
#df = pd.read_csv('../EDA_Prj/DATASET/건물용도별_거래량.csv')
#df = pd.read_csv('../EDA_Prj/DATASET/월간주택가격동향.csv')
#df = pd.read_csv('../EDA_Prj/DATASET/평균단위매매가격_아파트.xlsx')
#df = pd.read_csv('../EDA_Prj/DATASET/평균단위전세가격_아파트.xlsx')
#df = pd.read_csv('../EDA_Prj/DATASET/평균매매가격_아파트.xlsx')
#df = pd.read_csv('../EDA_Prj/DATASET/평균월세가격_아파트.xlsx')
#df = pd.read_csv('../EDA_Prj/DATASET/평균월세보증금_아파트.xlsx')
#df = pd.read_csv('../EDA_Prj/DATASET/평균전세가격_아파트.xlsx')
# Out:
#     기준연도  기준월  비아파트    아파트
# 0   2024    3  2616   3482
# 1   2024    2  2130   2665
# 2   2024    1  2243   2456
# 3   2023   12  2283   1790
# 4   2023   11  2544   2417
# ..   ...  ...   ...    ...
# 70  2018    5  6022   5697
# 71  2018    4  5812   6535
# 72  2018    3  9558  14609
# 73  2018    2  5809  11986
# 74  2018    1  5169   9938
#
# [75 rows x 4 columns]

# %%
df2.to_csv('df2.csv',encoding='UTF-8-SIG')

# %%
data2 = pd.read_csv('df2.csv',encoding='utf-8-sig')

data2
# Out:
#     Unnamed: 0  기준연도  기준월  비아파트    아파트
# 0            0  2024    3  2616   3482
# 1            1  2024    2  2130   2665
# 2            2  2024    1  2243   2456
# 3            3  2023   12  2283   1790
# 4            4  2023   11  2544   2417
# ..         ...   ...  ...   ...    ...
# 70          70  2018    5  6022   5697
# 71          71  2018    4  5812   6535
# 72          72  2018    3  9558  14609
# 73          73  2018    2  5809  11986
# 74          74  2018    1  5169   9938
#
# [75 rows x 5 columns]

# %%
df3 = data2.groupby(by=['기준연도','기준월']).mean()
df3
# Out:
#           Unnamed: 0    비아파트      아파트
# 기준연도 기준월
# 2018 1          74.0  5169.0   9938.0
#      2          73.0  5809.0  11986.0
#      3          72.0  9558.0  14609.0
#      4          71.0  5812.0   6535.0
#      5          70.0  6022.0   5697.0
# ...              ...     ...      ...
# 2023 11          4.0  2544.0   2417.0
#      12          3.0  2283.0   1790.0
# 2024 1           2.0  2243.0   2456.0
#      2           1.0  2130.0   2665.0
#      3           0.0  2616.0   3482.0
#
# [75 rows x 3 columns]

# %%
df3.to_csv('df3.csv',encoding='utf-8-sig')

# %%
import pandas as pd

data = pd.read_csv('../EDA_Prj/DATASET/월간주택가격동향.csv')
data
# Out:
#     기준연도  기준월   매매상승률  매매지수   전세상승률  전세지수   월세상승률   월세지수
# 0   2024    3  -0.12%  95.8   0.05%  92.6   0.09%  102.0
# 1   2024    2  -0.14%  95.9   0.03%  92.6   0.10%  101.9
# 2   2024    1  -0.14%  96.0   0.05%  92.5   0.07%  101.8
# 3   2023   12  -0.10%  96.2   0.12%  92.5   0.10%  101.7
# 4   2023   11   0.04%  96.3   0.27%  92.4   0.14%  101.6
# ..   ...  ...     ...   ...     ...   ...     ...    ...
# 70  2018    5  -0.03%  90.1  -0.28%  94.8  -0.12%   99.5
# 71  2018    4   0.06%  90.1  -0.19%  95.1  -0.10%   99.6
# 72  2018    3   0.12%  90.1  -0.13%  95.2  -0.07%   99.7
# 73  2018    2   0.20%  90.0  -0.09%  95.4  -0.05%   99.7
# 74  2018    1   0.14%  89.8  -0.05%  95.5  -0.04%   99.8
#
# [75 rows x 8 columns]

# %%
data.head()
# Out:
#    기준연도  기준월   매매상승률  매매지수  전세상승률  전세지수  월세상승률   월세지수
# 0  2024    3  -0.12%  95.8  0.05%  92.6  0.09%  102.0
# 1  2024    2  -0.14%  95.9  0.03%  92.6  0.10%  101.9
# 2  2024    1  -0.14%  96.0  0.05%  92.5  0.07%  101.8
# 3  2023   12  -0.10%  96.2  0.12%  92.5  0.10%  101.7
# 4  2023   11   0.04%  96.3  0.27%  92.4  0.14%  101.6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기준연도    75 non-null     int64
#  1   기준월     75 non-null     int64
#  2   매매상승률   75 non-null     object
#  3   매매지수    75 non-null     float64
#  4   전세상승률   75 non-null     object
#  5   전세지수    75 non-null     float64
#  6   월세상승률   75 non-null     object
#  7   월세지수    75 non-null     float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 4.8+ KB

# %%
data.describe()
# Out:
#               기준연도        기준월       매매지수        전세지수        월세지수
# count    75.000000  75.000000   75.00000   75.000000   75.000000
# mean   2020.640000   6.320000   95.57600   95.932000  100.068000
# std       1.820603   3.522745    5.32594    4.021031    1.685163
# min    2018.000000   1.000000   89.70000   91.400000   97.900000
# 25%    2019.000000   3.000000   90.40000   92.600000   98.500000
# 50%    2021.000000   6.000000   95.70000   94.200000   99.700000
# 75%    2022.000000   9.000000   99.30000   99.150000  101.650000
# max    2024.000000  12.000000  104.80000  103.300000  103.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
#matplotlib 패키지 한글 깨짐 처리 시작
import matplotlib.pyplot as plt
import platform
if platform.system() == 'Darwin': #맥
        plt.rc('font', family='AppleGothic') 
elif platform.system() == 'Windows': #윈도우
        plt.rc('font', family='Malgun Gothic') 
elif platform.system() == 'Linux': #리눅스 (구글 콜랩)
        #!wget "https://www.wfonts.com/download/data/2016/06/13/malgun-gothic/malgun.ttf"
        #!mv malgun.ttf /usr/share/fonts/truetype/
        #import matplotlib.font_manager as fm 
        #fm._rebuild() 
        plt.rc('font', family='Malgun Gothic') 
plt.rcParams['axes.unicode_minus'] = False #한글 폰트 사용시 마이너스 폰트 깨짐 해결
#matplotlib 패키지 한글 깨짐 처리 끝

# Creating a figure to contain the plots
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(24, 18))

# Flattening the array of axes for easy iteration
axes = axes.flatten()

# Loop through each column in the data except the date columns and plot histograms
for i, column in enumerate(data.columns[2:]):  # Skipping '기준년도' and '기준월'
    sns.histplot(data[column], kde=True, ax=axes[i])
    axes[i].set_title(column, fontsize=9)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

# Remove unused axes
for ax in axes[i+1:]:
    ax.remove()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Selecting a subset of columns for violin plots for clarity
selected_columns = ['매매상승률', '매매지수', '전세상승률', '전세지수', '월세상승률', '월세지수']


# Strip unnecessary spaces from column names
data.columns = data.columns.str.strip()

# Re-attempt to create violin plots with corrected column names
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 12))
axes = axes.flatten()

# Loop through the selected columns and plot violin plots
for i, column in enumerate(selected_columns):
    sns.violinplot(x=data[column], ax=axes[i])
    axes[i].set_title(column, fontsize=10)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Create a datetime index from the '기준연도' and '기준월'
data['날짜'] = pd.to_datetime(data['기준연도'].astype(str) + '-' + data['기준월'].astype(str))

# Plotting time series data for apartment sales and rental price indices
plt.figure(figsize=(14, 7))
plt.plot(data['날짜'], data['매매상승률'], label='매매상승률', marker='o')
plt.plot(data['날짜'], data['전세상승률'], label='전세상승률', marker='x')

plt.title('시간에 따른 매매가격 상승률 과 전세가격 상승률의 변화')
plt.xlabel('날짜')
plt.ylabel('상승률 지수')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()

# Plotting the heatmap of the correlation matrix
plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title('변수들 간의 상관 관계 히트맵')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\cchok\AppData\Local\Temp\ipykernel_4520\3429850979.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
# Correcting the subplot indices and the total number of plots
plt.figure(figsize=(18, 12))

# Apartment sales price index
plt.subplot(4, 1, 1)
plt.plot(data['날짜'], data['매매지수'], label='매매지수', color='blue')
plt.title('월간 주택 가격 매매지수 및 주요 경제 지표')
plt.ylabel('가격 지수')
plt.legend()
plt.xlabel('날짜')
plt.tight_layout()
plt.show()

# %%
df4 = pd.read_csv('../EDA_Prj/DATASET/건물용도별_거래량.csv')
df4
# Out:
#     기준연도  기준월 건물용도별_합계  주거용_소계   단독주택  다가구주택  다세대주택   연립주택     아파트 상업업무용_소계  \
# 0   2018    1   34,311  25,583  1,534    226  4,948    663  18,212    6,642
# 1   2018    2   29,839  23,538  1,476    241  5,724    792  15,305    5,175
# 2   2018    3   41,973  33,600  2,568    420  8,633  1,306  20,673    7,311
# 3   2018    4   24,652  18,594  1,696    310  5,845    613  10,130    4,874
# 4   2018    5   27,287  20,538  1,711    322  5,428    765  12,312    5,762
# ..   ...  ...      ...     ...    ...    ...    ...    ...     ...      ...
# 70  2023   11   13,018   9,534    358    170  2,518    353   6,135    2,503
# 71  2023   12   13,312   9,177    341    142  2,486    203   6,005    2,886
# 72  2024    1   12,323   9,121    269    116  2,488    253   5,995    2,170
# 73  2024    2   10,535   7,780    230    102  2,177    247   5,024    2,213
# 74  2024    3   11,848   7,991    321    150  2,807    249   4,464    2,793
#
#       공업용   기타건물  나지
# 0   1,033  1,053   0
# ...

# %%
df5 = pd.read_excel('../EDA_Prj/DATASET/평균단위매매가격_아파트.xlsx')
df6 = pd.read_excel('../EDA_Prj/DATASET/평균단위전세가격_아파트.xlsx')
df7 = pd.read_excel('../EDA_Prj/DATASET/평균매매가격_아파트.xlsx')
df8 = pd.read_excel('../EDA_Prj/DATASET/평균월세가격_아파트.xlsx')
df9 = pd.read_excel('../EDA_Prj/DATASET/평균월세보증금_아파트.xlsx')
df10 = pd.read_excel('../EDA_Prj/DATASET/평균전세가격_아파트.xlsx')


df5
#df6
#df7
#df8
#df9
#df10
# Out:
#     기준연도  기준월    전국   수도권   지방권  6대광역시  5대광역시   9개도   8개도     서울  ...   구로구  \
# 0   2018    1  3960  5363  2630   3212   3169  3081  2139   8162  ...  5701
# 1   2018    2  3989  5425  2627   3212   3169  3088  2133   8310  ...  5749
# 2   2018    3  4003  5458  2624   3213   3169  3093  2128   8379  ...  5774
# 3   2018    4  4008  5472  2620   3212   3169  3095  2120   8404  ...  5818
# 4   2018    5  4007  5478  2613   3210   3167  3092  2108   8413  ...  5854
# ..   ...  ...   ...   ...   ...    ...    ...   ...   ...    ...  ...   ...
# 70  2023   11  5535  8151  3175   4074   3923  4370  2492  12608  ...  8092
# 71  2023   12  5527  8138  3171   4066   3916  4364  2490  12591  ...  8063
# 72  2024    1  5569  8163  3217   4128   3976  4410  2520  12632  ...  8059
# 73  2024    2  5556  8147  3208   4117   3964  4399  2516  12615  ...  8049
# 74  2024    3  5548  8139  3200   4108   3953  4389  2512  12619  ...  8034
#
# ...
